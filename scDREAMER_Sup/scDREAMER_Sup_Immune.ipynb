# %% [markdown]
# <a href="https://colab.research.google.com/github/Zafar-Lab/scDREAMER/blob/main/2109_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
import random
import numpy as np
import tensorflow as tf2
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# 2023-09-25 16:32:16.900683: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-25 16:32:17.581215: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
np.random.seed(0)
tf.set_random_seed(0)
random.seed(0)
tf2.random.set_seed(0)
tf2.keras.utils.set_random_seed(0)

# %%
import warnings
warnings.filterwarnings('ignore')
"""
# !pip install -U scipy==1.5.0
# !pip install scanpy==1.8.2
# !pip install -U scikit-learn
"""
# Out:
# '\n!pip install -U scipy==1.5.0\n!pip install scanpy==1.8.2\n!pip install -U scikit-learn\n'

# %% [markdown]
# Building model

# %%
name = "Immune_Human"

"""
NOTE:
Run setting as follows:
0: Supervised setting
10: 10 percent missing labels data
20: 20 percent missing labels data
50: 50 percent missing labels data
"""
run_setting = 0

# %%
"""

0: Supervised setting
10: 10% missing labels
20: 20% missing labels
50: 50% missing labels

"""

path = "/home/ajita/Documents/data_integration/"

data_path = {
    
"Immune_Human" : {0: path + "Immune/Immune_ALL_human.h5ad",
                  10: path + "Immune/Immune_Human_NA_0.1.h5ad",
                  20: path + "Immune/Immune_Human_NA_0.2.h5ad",
                  50: path + "Immune/Immune_Human_NA_0.5.h5ad"
                 },
    
"Human_Mouse" : {
                0: path + "hum_mou/hcl_mca_merged.h5ad"},
    
"Human_Retina" : {
                0: path + "Human_Retina/Human_Retina.h5ad"},
    
"Lung" : { 0: path + "Lung/Lung_atlas_public.h5ad",
          10: path + "Lung/Lung_NA_0.1.h5ad",
          20: path + "Lung/Lung_NA_0.2.h5ad",
          50: path + "Lung/Lung_NA_0.5.h5ad"
         },
    
"Healthy_Heart" : {
        0: path + "Healthy_Heart/Healthy_human_heart_adata.h5ad",
        20: path + "Healthy_Heart/Healthy_human_heart_adata_NA_0.2.h5ad",
        50: path + "Healthy_Heart/Healthy_human_heart_adata_NA_0.5.h5ad"}
}


batch_key_dict = {'Immune_Human' : 'batch',
                 'Lung' : 'batch',
                 'Pancreas' : 'tech',
                 'Human_Mouse' : 'batch',
                 'Human_Retina': "Batch",
                 "Healthy_Heart" : "sampleID"
                 
                }

cell_type_key_dict = {
    
"Immune_Human" : {0: "final_annotation", 10: "final_annotation_NA",
                  20: "final_annotation_NA", 50: "final_annotation_NA"
                 },
    
"Human_Mouse" : {
                0: "celltype"},
    
"Human_Retina" : {
                0: "Subcluster"},
    
"Lung" : { 0: "cell_type",
          10: "cell_type_NA",
          20: "cell_type_NA",
          50: "cell_type_NA"
         },
    
"Healthy_Heart" : {
        0: "celltype",
        20: "celltype_NA",
        50: "celltype_NA"},
    
"Human_Mouse" : {
     0: "celltype"
    }    
}
 
shuffle_type_dict = {
"Immune_Human" : {0: 1, 10: 2, 20: 2, 50: 2 },    
"Human_Retina" : { 0: 1},
"Lung" : { 0: 1,10: 2, 20: 2, 50: 2}, 
"Healthy_Heart" : {0: 1, 20: 1,50: 1},    
"Human_Mouse" : {0: 1}}

lr = {"lr_ae" : 0.0002, "lr_dis": 0.0007, "lr_bc": 0.0007}
lr_big_data = {"lr_ae" : 0.0002, "lr_dis": 0.00001, "lr_bc": 0.0007}

learning_rate = {
"Immune_Human" : {0: lr, 10: lr, 20: lr, 50: lr },    
"Human_Retina" : { 0: lr},
"Lung" : { 0: lr,10: lr, 20: lr, 50: lr}, 
"Healthy_Heart" : {0: lr_big_data, 20: lr_big_data, 50: lr_big_data},    
"Human_Mouse" : {0: {"lr_ae" : 0.00005, "lr_dis": 0.00001, "lr_bc": 0.0007}}}


# big datasets: 20 dimensions
latent_dim = {
                'Immune_Human' : 10,
                 'Lung' : 10,
                 'Pancreas' : 10,
                 'Human_Mouse' : 20,
                 'Human_Retina': 10,
                 "Healthy_Heart" : 20
    
            }

BS = {
"Immune_Human" : {0: 256, 10: 128, 20: 128, 50: 128 },    
"Human_Retina" : { 0: 256},
"Lung" : { 0: 256,10: 128, 20: 128, 50: 128}, 
"Healthy_Heart" : {0: 128, 20: 128,50: 128},    
"Human_Mouse" : {0: 128}}


epoch_dict = {
    'Immune_Human' : 300,
     'Lung' : 300,
     'Human_Mouse' : 300,
     'Human_Retina': 300,
     "Healthy_Heart" : 300
}

plot_cell_type_dict = {
                    "Healthy_Heart" : "celltype",
                    'Immune_Human' : 'final_annotation', 
                 'Lung' : 'cell_type',
                 'Pancreas' : 'celltype',
                 'Human_Mouse' : "celltype",
                 "Human_Retina":"Subcluster"
                    } 

"""
Below variable takes care of sparse matrix
If 1: pd.DataFrame.sparse.from_spmatrix(Ann.X) is used
If 0: pd.DataFrame(Ann.X)

By default 0, unless scarcity not handled by basis pandas operation
"""

sparseIP= {
        "Healthy_Heart" : 1,
    'Immune_Human' : 0, 
     'Lung' : 1,
     'Pancreas' : 0,
     'Human_Mouse' : 1,
     "Human_Retina": 0
}

# %%
# Add avg of losses

import src.model as model


run_config = tf.ConfigProto()

run_config.gpu_options.per_process_gpu_memory_fraction = 0.333
run_config.gpu_options.allow_growth = True

with tf.Session(config = run_config) as sess:

    dreamer = model.scDREAMER(
        sess,
        epoch = epoch_dict[name],
        dataset_name = data_path[name][run_setting],
        batch = batch_key_dict[name],
        cell_type = cell_type_key_dict[name][run_setting],
        plot_cell_type = plot_cell_type_dict[name],
        name = name,
        lr_ae = learning_rate[name][run_setting]['lr_ae'],
        lr_dis = learning_rate[name][run_setting]['lr_dis'],
        lr_bc = learning_rate[name][run_setting]['lr_bc'],
        batch_size = BS[name][run_setting],
        z_dim = latent_dim[name],
        shuffle_type = shuffle_type_dict[name][run_setting],
        sparseIP = sparseIP[name]
        )

    dreamer.train_cluster()
# Out:
# 2023-09-25 16:32:20.380508: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5367 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:d8:00.0, compute capability: 7.5
# Loading dataset
# Preprocessing...
# here [2 4 1 ... 1 2 2]
# Shape self.data_train: (33506, 2000)
# Shape self.data_test: (33506, 2000)
# encoder input shape  Tensor("concat:0", shape=(?, 2010), dtype=float32)
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# decoder input shape  Tensor("concat_2:0", shape=(?, 20), dtype=float32)
# inferred check Tensor("Max:0", shape=(), dtype=float32)
# entering in for loop 1   512  -- > 256
# KL gaussian z Tensor("mul_13:0", shape=(?,), dtype=float32)
# KL gaussian l Tensor("mul_12:0", shape=(?,), dtype=float32)
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Cluster DRA on DataSet /home/ajita/Documents/data_integration/Immune/Immune_ALL_human.h5ad ...
# 2023-09-25 16:32:36.745832: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# Epoch : [0] ,  a_loss = 447.2831, d_loss: -0.0166 , db_loss: 2.0159
# Epoch : [1] ,  a_loss = 440.3687, d_loss: -0.2286 , db_loss: 1.6726
# Epoch : [2] ,  a_loss = 418.7642, d_loss: -0.2528 , db_loss: 1.5301
# Epoch : [3] ,  a_loss = 422.3308, d_loss: -0.3176 , db_loss: 1.4365
# Epoch : [4] ,  a_loss = 409.5872, d_loss: -1.2763 , db_loss: 1.5439
# Epoch : [5] ,  a_loss = 405.9718, d_loss: -1.6753 , db_loss: 1.5118
# Epoch : [6] ,  a_loss = 409.4523, d_loss: -1.7804 , db_loss: 1.5908
# Epoch : [7] ,  a_loss = 404.2825, d_loss: -0.6542 , db_loss: 1.5755
# Epoch : [8] ,  a_loss = 414.4922, d_loss: -0.3211 , db_loss: 1.4694
# Epoch : [9] ,  a_loss = 398.7779, d_loss: -0.1814 , db_loss: 1.5102
# Epoch : [10] ,  a_loss = 406.2830, d_loss: -1.2892 , db_loss: 1.5625
# Epoch : [11] ,  a_loss = 405.4329, d_loss: -0.7041 , db_loss: 1.5352
# Epoch : [12] ,  a_loss = 396.8889, d_loss: -0.3090 , db_loss: 1.5336
# Epoch : [13] ,  a_loss = 392.9378, d_loss: -0.4251 , db_loss: 1.6367
# Epoch : [14] ,  a_loss = 378.2116, d_loss: -0.3211 , db_loss: 1.6333
# Epoch : [15] ,  a_loss = 389.9807, d_loss: -0.7346 , db_loss: 1.5289
# Epoch : [16] ,  a_loss = 390.8220, d_loss: -0.0818 , db_loss: 1.4521
# Epoch : [17] ,  a_loss = 380.7636, d_loss: -0.7386 , db_loss: 1.6506
# Epoch : [18] ,  a_loss = 393.5179, d_loss: -1.0593 , db_loss: 1.5454
# Epoch : [19] ,  a_loss = 385.0590, d_loss: -0.6507 , db_loss: 1.7393
# Epoch : [20] ,  a_loss = 380.5733, d_loss: -0.7135 , db_loss: 1.4613
# Epoch : [21] ,  a_loss = 386.6740, d_loss: -0.8790 , db_loss: 1.4571
# Epoch : [22] ,  a_loss = 377.3741, d_loss: -0.7908 , db_loss: 1.5970
# Epoch : [23] ,  a_loss = 388.9605, d_loss: -0.4380 , db_loss: 1.5082
# Epoch : [24] ,  a_loss = 376.0531, d_loss: -0.3626 , db_loss: 1.6282
# Epoch : [25] ,  a_loss = 375.3375, d_loss: -0.6113 , db_loss: 1.6067
# Epoch : [26] ,  a_loss = 373.9372, d_loss: -0.2299 , db_loss: 1.6275
# Epoch : [27] ,  a_loss = 381.2567, d_loss: -0.5783 , db_loss: 1.4886
# Epoch : [28] ,  a_loss = 376.1999, d_loss: -0.2564 , db_loss: 1.5285
# Epoch : [29] ,  a_loss = 375.2140, d_loss: -0.4059 , db_loss: 1.5183
# Epoch : [30] ,  a_loss = 372.4513, d_loss: -0.5431 , db_loss: 1.6401
# Epoch : [31] ,  a_loss = 380.7669, d_loss: -0.8630 , db_loss: 1.6224
# Epoch : [32] ,  a_loss = 377.4243, d_loss: -0.9171 , db_loss: 1.5509
# Epoch : [33] ,  a_loss = 371.4210, d_loss: -0.3282 , db_loss: 1.5871
# Epoch : [34] ,  a_loss = 370.0763, d_loss: -0.7693 , db_loss: 1.5399
# Epoch : [35] ,  a_loss = 369.9227, d_loss: -0.3754 , db_loss: 1.5394
# Epoch : [36] ,  a_loss = 358.7238, d_loss: -0.4117 , db_loss: 1.6361
# Epoch : [37] ,  a_loss = 372.7506, d_loss: -0.5130 , db_loss: 1.5819
# Epoch : [38] ,  a_loss = 366.0416, d_loss: -0.2821 , db_loss: 1.6191
# Epoch : [39] ,  a_loss = 372.6831, d_loss: -0.2909 , db_loss: 1.5315
# Epoch : [40] ,  a_loss = 364.8473, d_loss: -0.1463 , db_loss: 1.6285
# Epoch : [41] ,  a_loss = 357.8241, d_loss: -0.3042 , db_loss: 1.5720
# Epoch : [42] ,  a_loss = 372.7934, d_loss: -0.1935 , db_loss: 1.5319
# Epoch : [43] ,  a_loss = 362.4806, d_loss: -0.5518 , db_loss: 1.6414
# Epoch : [44] ,  a_loss = 368.1844, d_loss: -0.4610 , db_loss: 1.6213
# Epoch : [45] ,  a_loss = 361.3227, d_loss: -0.3147 , db_loss: 1.6612
# Epoch : [46] ,  a_loss = 358.1465, d_loss: -0.3748 , db_loss: 1.6289
# Epoch : [47] ,  a_loss = 360.4926, d_loss: -0.2963 , db_loss: 1.6216
# Epoch : [48] ,  a_loss = 361.3619, d_loss: -0.3519 , db_loss: 1.5914
# Epoch : [49] ,  a_loss = 363.0772, d_loss: -0.2608 , db_loss: 1.5855
# Epoch : [50] ,  a_loss = 357.0645, d_loss: -0.8212 , db_loss: 1.6140
# Epoch : [51] ,  a_loss = 362.2968, d_loss: -0.5642 , db_loss: 1.5294
# Epoch : [52] ,  a_loss = 357.8798, d_loss: -0.3328 , db_loss: 1.6124
# Epoch : [53] ,  a_loss = 360.2349, d_loss: -0.0566 , db_loss: 1.6320
# Epoch : [54] ,  a_loss = 361.2990, d_loss: -0.3252 , db_loss: 1.6242
# Epoch : [55] ,  a_loss = 357.6290, d_loss: 0.0069 , db_loss: 1.6727
# Epoch : [56] ,  a_loss = 353.0441, d_loss: -0.2296 , db_loss: 1.7091
# Epoch : [57] ,  a_loss = 361.5281, d_loss: -0.2503 , db_loss: 1.5839
# Epoch : [58] ,  a_loss = 363.3451, d_loss: -0.2323 , db_loss: 1.7358
# Epoch : [59] ,  a_loss = 353.4018, d_loss: -0.2440 , db_loss: 1.5866
# Epoch : [60] ,  a_loss = 361.9908, d_loss: -0.1092 , db_loss: 1.5882
# Epoch : [61] ,  a_loss = 353.7645, d_loss: -0.1288 , db_loss: 1.6420
# Epoch : [62] ,  a_loss = 357.2856, d_loss: -0.3624 , db_loss: 1.5306
# Epoch : [63] ,  a_loss = 351.9330, d_loss: -0.2738 , db_loss: 1.7227
# Epoch : [64] ,  a_loss = 343.2054, d_loss: -0.4520 , db_loss: 1.7195
# Epoch : [65] ,  a_loss = 354.4390, d_loss: -0.6115 , db_loss: 1.6396
# Epoch : [66] ,  a_loss = 356.0524, d_loss: -0.4833 , db_loss: 1.6319
# Epoch : [67] ,  a_loss = 354.7055, d_loss: -0.4320 , db_loss: 1.6179
# Epoch : [68] ,  a_loss = 349.7876, d_loss: -0.1870 , db_loss: 1.6687
# Epoch : [69] ,  a_loss = 356.7354, d_loss: -0.3201 , db_loss: 1.5304
# Epoch : [70] ,  a_loss = 342.7111, d_loss: -0.2027 , db_loss: 1.6924
# Epoch : [71] ,  a_loss = 343.6087, d_loss: -0.2485 , db_loss: 1.7236
# Epoch : [72] ,  a_loss = 349.4704, d_loss: -0.1687 , db_loss: 1.5723
# Epoch : [73] ,  a_loss = 333.8009, d_loss: -0.3621 , db_loss: 1.6888
# Epoch : [74] ,  a_loss = 349.2035, d_loss: -0.3967 , db_loss: 1.5889
# Epoch : [75] ,  a_loss = 352.8183, d_loss: -0.2228 , db_loss: 1.6822
# Epoch : [76] ,  a_loss = 342.0801, d_loss: -0.5062 , db_loss: 1.7145
# Epoch : [77] ,  a_loss = 342.4239, d_loss: -0.4438 , db_loss: 1.6359
# Epoch : [78] ,  a_loss = 342.9614, d_loss: -0.2506 , db_loss: 1.5308
# Epoch : [79] ,  a_loss = 344.9725, d_loss: -0.3610 , db_loss: 1.6333
# Epoch : [80] ,  a_loss = 353.5344, d_loss: -0.2244 , db_loss: 1.5974
# Epoch : [81] ,  a_loss = 351.2739, d_loss: -0.1835 , db_loss: 1.5633
# Epoch : [82] ,  a_loss = 342.9129, d_loss: -0.2254 , db_loss: 1.6650
# Epoch : [83] ,  a_loss = 343.0721, d_loss: -0.6256 , db_loss: 1.6400
# Epoch : [84] ,  a_loss = 341.2471, d_loss: -0.3969 , db_loss: 1.6043
# Epoch : [85] ,  a_loss = 353.7092, d_loss: -0.5850 , db_loss: 1.5157
# Epoch : [86] ,  a_loss = 343.8206, d_loss: -0.3544 , db_loss: 1.6368
# Epoch : [87] ,  a_loss = 344.4641, d_loss: -0.3908 , db_loss: 1.6101
# Epoch : [88] ,  a_loss = 342.6795, d_loss: 0.0089 , db_loss: 1.6759
# Epoch : [89] ,  a_loss = 341.0710, d_loss: -0.4694 , db_loss: 1.5942
# Epoch : [90] ,  a_loss = 343.0565, d_loss: -0.3211 , db_loss: 1.5594
# Epoch : [91] ,  a_loss = 338.2848, d_loss: -0.3043 , db_loss: 1.7309
# Epoch : [92] ,  a_loss = 344.3213, d_loss: 0.0525 , db_loss: 1.6124
# Epoch : [93] ,  a_loss = 345.1310, d_loss: -0.4871 , db_loss: 1.6969
# Epoch : [94] ,  a_loss = 345.4628, d_loss: -0.3917 , db_loss: 1.6085
# Epoch : [95] ,  a_loss = 340.2184, d_loss: -0.2233 , db_loss: 1.6976
# Epoch : [96] ,  a_loss = 343.8742, d_loss: -0.1323 , db_loss: 1.6357
# Epoch : [97] ,  a_loss = 336.6369, d_loss: -0.4127 , db_loss: 1.7546
# Epoch : [98] ,  a_loss = 339.2832, d_loss: -0.4454 , db_loss: 1.6227
# Epoch : [99] ,  a_loss = 343.3040, d_loss: -0.3008 , db_loss: 1.5907
# Epoch : [100] ,  a_loss = 349.6667, d_loss: -0.3200 , db_loss: 1.6412
# Epoch : [101] ,  a_loss = 331.7807, d_loss: -0.3617 , db_loss: 1.7594
# Epoch : [102] ,  a_loss = 345.1008, d_loss: -0.0993 , db_loss: 1.5492
# Epoch : [103] ,  a_loss = 340.5298, d_loss: -0.0670 , db_loss: 1.5634
# Epoch : [104] ,  a_loss = 340.8385, d_loss: -0.1355 , db_loss: 1.6322
# Epoch : [105] ,  a_loss = 339.3922, d_loss: -0.1572 , db_loss: 1.6318
# Epoch : [106] ,  a_loss = 345.7924, d_loss: -0.1898 , db_loss: 1.6721
# Epoch : [107] ,  a_loss = 346.0625, d_loss: -0.1259 , db_loss: 1.6101
# Epoch : [108] ,  a_loss = 335.3673, d_loss: -0.2247 , db_loss: 1.6655
# Epoch : [109] ,  a_loss = 338.7318, d_loss: -0.2233 , db_loss: 1.6671
# Epoch : [110] ,  a_loss = 334.6545, d_loss: -0.3761 , db_loss: 1.7106
# Epoch : [111] ,  a_loss = 340.9415, d_loss: -0.2582 , db_loss: 1.7041
# Epoch : [112] ,  a_loss = 332.8555, d_loss: -0.5165 , db_loss: 1.6531
# Epoch : [113] ,  a_loss = 337.3587, d_loss: -0.4584 , db_loss: 1.6471
# Epoch : [114] ,  a_loss = 336.7406, d_loss: -0.2923 , db_loss: 1.6974
# Epoch : [115] ,  a_loss = 342.6296, d_loss: -0.5125 , db_loss: 1.6550
# Epoch : [116] ,  a_loss = 340.9677, d_loss: -0.4233 , db_loss: 1.5999
# Epoch : [117] ,  a_loss = 336.5417, d_loss: -0.4451 , db_loss: 1.6358
# Epoch : [118] ,  a_loss = 327.5593, d_loss: -0.0200 , db_loss: 1.7152
# Epoch : [119] ,  a_loss = 337.9682, d_loss: -0.0162 , db_loss: 1.7003
# Epoch : [120] ,  a_loss = 335.4896, d_loss: -0.0123 , db_loss: 1.7179
# Epoch : [121] ,  a_loss = 340.5697, d_loss: -0.0094 , db_loss: 1.5684
# Epoch : [122] ,  a_loss = 334.1050, d_loss: -0.0087 , db_loss: 1.6718
# Epoch : [123] ,  a_loss = 333.3666, d_loss: -0.0069 , db_loss: 1.6903
# Epoch : [124] ,  a_loss = 337.9978, d_loss: -0.0064 , db_loss: 1.5696
# Epoch : [125] ,  a_loss = 339.5130, d_loss: -0.0062 , db_loss: 1.6191
# Epoch : [126] ,  a_loss = 339.7994, d_loss: -0.0040 , db_loss: 1.7358
# Epoch : [127] ,  a_loss = 342.4346, d_loss: -0.0050 , db_loss: 1.5507
# Epoch : [128] ,  a_loss = 331.6218, d_loss: -0.0045 , db_loss: 1.7026
# Epoch : [129] ,  a_loss = 337.1452, d_loss: -0.0054 , db_loss: 1.6548
# Epoch : [130] ,  a_loss = 337.4349, d_loss: -0.0039 , db_loss: 1.7239
# Epoch : [131] ,  a_loss = 335.1758, d_loss: -0.0035 , db_loss: 1.6670
# Epoch : [132] ,  a_loss = 336.4121, d_loss: -0.0033 , db_loss: 1.6514
# Epoch : [133] ,  a_loss = 338.3516, d_loss: -0.0028 , db_loss: 1.6176
# Epoch : [134] ,  a_loss = 337.5798, d_loss: -0.0026 , db_loss: 1.5794
# Epoch : [135] ,  a_loss = 339.1155, d_loss: -0.0031 , db_loss: 1.6569
# Epoch : [136] ,  a_loss = 335.3145, d_loss: -0.0032 , db_loss: 1.6498
# Epoch : [137] ,  a_loss = 336.4568, d_loss: -0.0027 , db_loss: 1.7148
# Epoch : [138] ,  a_loss = 332.0188, d_loss: -0.0028 , db_loss: 1.6402
# Epoch : [139] ,  a_loss = 338.4686, d_loss: -0.0025 , db_loss: 1.7209
# Epoch : [140] ,  a_loss = 344.0839, d_loss: -0.0029 , db_loss: 1.5729
# Epoch : [141] ,  a_loss = 335.9547, d_loss: -0.0027 , db_loss: 1.5442
# Epoch : [142] ,  a_loss = 331.6467, d_loss: -0.0020 , db_loss: 1.6502
# Epoch : [143] ,  a_loss = 339.8665, d_loss: -0.0027 , db_loss: 1.6672
# Epoch : [144] ,  a_loss = 335.0636, d_loss: -0.0024 , db_loss: 1.5984
# Epoch : [145] ,  a_loss = 331.7826, d_loss: -0.0022 , db_loss: 1.7989
# Epoch : [146] ,  a_loss = 337.3206, d_loss: -0.0024 , db_loss: 1.7200
# Epoch : [147] ,  a_loss = 332.1257, d_loss: -0.0021 , db_loss: 1.6415
# Epoch : [148] ,  a_loss = 335.8036, d_loss: -0.0020 , db_loss: 1.5775
# Epoch : [149] ,  a_loss = 333.5409, d_loss: -0.0022 , db_loss: 1.6347
# Epoch : [150] ,  a_loss = 344.1252, d_loss: -0.0016 , db_loss: 1.6247
# Epoch : [151] ,  a_loss = 336.1908, d_loss: -0.0023 , db_loss: 1.5532
# Epoch : [152] ,  a_loss = 329.3839, d_loss: -0.0021 , db_loss: 1.6230
# Epoch : [153] ,  a_loss = 327.8549, d_loss: -0.0026 , db_loss: 1.6866
# Epoch : [154] ,  a_loss = 332.3202, d_loss: -0.0019 , db_loss: 1.6975
# Epoch : [155] ,  a_loss = 333.3529, d_loss: -0.0020 , db_loss: 1.7236
# Epoch : [156] ,  a_loss = 339.4319, d_loss: -0.0016 , db_loss: 1.6256
# Epoch : [157] ,  a_loss = 330.7913, d_loss: -0.0019 , db_loss: 1.6396
# Epoch : [158] ,  a_loss = 323.5029, d_loss: -0.0018 , db_loss: 1.7510
# Epoch : [159] ,  a_loss = 332.7750, d_loss: -0.0018 , db_loss: 1.6555
# Epoch : [160] ,  a_loss = 334.0242, d_loss: -0.0019 , db_loss: 1.6176
# Epoch : [161] ,  a_loss = 330.3781, d_loss: -0.0020 , db_loss: 1.5984
# Epoch : [162] ,  a_loss = 323.2681, d_loss: -0.0021 , db_loss: 1.6797
# Epoch : [163] ,  a_loss = 331.9048, d_loss: -0.0017 , db_loss: 1.5810
# Epoch : [164] ,  a_loss = 336.5227, d_loss: -0.0017 , db_loss: 1.7201
# Epoch : [165] ,  a_loss = 327.7292, d_loss: -0.0017 , db_loss: 1.6623
# Epoch : [166] ,  a_loss = 333.4577, d_loss: -0.0018 , db_loss: 1.6092
# Epoch : [167] ,  a_loss = 336.4784, d_loss: -0.0017 , db_loss: 1.6087
# Epoch : [168] ,  a_loss = 334.0528, d_loss: -0.0020 , db_loss: 1.5348
# Epoch : [169] ,  a_loss = 329.1735, d_loss: -0.0018 , db_loss: 1.6473
# Epoch : [170] ,  a_loss = 330.6153, d_loss: -0.0014 , db_loss: 1.6260
# Epoch : [171] ,  a_loss = 335.0682, d_loss: -0.0016 , db_loss: 1.6204
# Epoch : [172] ,  a_loss = 338.1070, d_loss: -0.0016 , db_loss: 1.6520
# Epoch : [173] ,  a_loss = 334.9922, d_loss: -0.0014 , db_loss: 1.6662
# Epoch : [174] ,  a_loss = 330.2659, d_loss: -0.0015 , db_loss: 1.6823
# Epoch : [175] ,  a_loss = 334.7581, d_loss: -0.0015 , db_loss: 1.7723
# Epoch : [176] ,  a_loss = 326.0510, d_loss: -0.0016 , db_loss: 1.7017
# Epoch : [177] ,  a_loss = 324.0880, d_loss: -0.0012 , db_loss: 1.6376
# Epoch : [178] ,  a_loss = 328.8839, d_loss: -0.0015 , db_loss: 1.6531
# Epoch : [179] ,  a_loss = 334.4093, d_loss: -0.0013 , db_loss: 1.6067
# Epoch : [180] ,  a_loss = 334.4430, d_loss: -0.0012 , db_loss: 1.6552
# Epoch : [181] ,  a_loss = 323.3265, d_loss: -0.0015 , db_loss: 1.7901
# Epoch : [182] ,  a_loss = 331.1765, d_loss: -0.0014 , db_loss: 1.5834
# Epoch : [183] ,  a_loss = 327.1878, d_loss: -0.0012 , db_loss: 1.5717
# Epoch : [184] ,  a_loss = 328.7426, d_loss: -0.0013 , db_loss: 1.7195
# Epoch : [185] ,  a_loss = 331.6081, d_loss: -0.0014 , db_loss: 1.7485
# Epoch : [186] ,  a_loss = 336.5773, d_loss: -0.0014 , db_loss: 1.6350
# Epoch : [187] ,  a_loss = 327.4312, d_loss: -0.0016 , db_loss: 1.6429
# Epoch : [188] ,  a_loss = 334.7906, d_loss: -0.0205 , db_loss: 1.6438
# Epoch : [189] ,  a_loss = 325.7592, d_loss: -0.0461 , db_loss: 1.6463
# Epoch : [190] ,  a_loss = 332.0629, d_loss: -0.2120 , db_loss: 1.7343
# Epoch : [191] ,  a_loss = 333.3875, d_loss: -0.5473 , db_loss: 1.6585
# Epoch : [192] ,  a_loss = 335.1154, d_loss: -0.5249 , db_loss: 1.6739
# Epoch : [193] ,  a_loss = 327.4413, d_loss: -0.7499 , db_loss: 1.6682
# Epoch : [194] ,  a_loss = 330.2823, d_loss: -0.8224 , db_loss: 1.6193
# Epoch : [195] ,  a_loss = 327.8326, d_loss: -0.6086 , db_loss: 1.7409
# Epoch : [196] ,  a_loss = 328.1955, d_loss: -0.8717 , db_loss: 1.8038
# Epoch : [197] ,  a_loss = 334.4467, d_loss: -1.0221 , db_loss: 1.6261
# Epoch : [198] ,  a_loss = 330.9832, d_loss: -0.7301 , db_loss: 1.5974
# Epoch : [199] ,  a_loss = 326.1488, d_loss: -1.2513 , db_loss: 1.7200
# Epoch : [200] ,  a_loss = 326.8253, d_loss: -1.1105 , db_loss: 1.6727
# Epoch : [201] ,  a_loss = 332.6159, d_loss: -0.7912 , db_loss: 1.6995
# Epoch : [202] ,  a_loss = 331.2431, d_loss: -1.0654 , db_loss: 1.6391
# Epoch : [203] ,  a_loss = 332.5490, d_loss: -0.9757 , db_loss: 1.5244
# Epoch : [204] ,  a_loss = 324.2119, d_loss: -0.8295 , db_loss: 1.7410
# Epoch : [205] ,  a_loss = 329.7607, d_loss: -1.1755 , db_loss: 1.6415
# Epoch : [206] ,  a_loss = 336.8416, d_loss: -0.8924 , db_loss: 1.6283
# Epoch : [207] ,  a_loss = 333.3036, d_loss: -1.4861 , db_loss: 1.6080
# Epoch : [208] ,  a_loss = 335.0630, d_loss: -1.2935 , db_loss: 1.5992
# Epoch : [209] ,  a_loss = 330.5810, d_loss: -1.0451 , db_loss: 1.6988
# Epoch : [210] ,  a_loss = 324.5821, d_loss: -1.2026 , db_loss: 1.6768
# Epoch : [211] ,  a_loss = 335.2199, d_loss: -1.3520 , db_loss: 1.5896
# Epoch : [212] ,  a_loss = 329.1866, d_loss: -1.1727 , db_loss: 1.6271
# Epoch : [213] ,  a_loss = 328.8592, d_loss: -1.4311 , db_loss: 1.7743
# Epoch : [214] ,  a_loss = 331.6588, d_loss: -1.3702 , db_loss: 1.6749
# Epoch : [215] ,  a_loss = 325.3085, d_loss: -1.2866 , db_loss: 1.7290
# Epoch : [216] ,  a_loss = 330.1089, d_loss: -1.4999 , db_loss: 1.7217
# Epoch : [217] ,  a_loss = 322.2690, d_loss: -1.3992 , db_loss: 1.6922
# Epoch : [218] ,  a_loss = 332.2760, d_loss: -1.0881 , db_loss: 1.6996
# Epoch : [219] ,  a_loss = 333.4649, d_loss: -1.3776 , db_loss: 1.6414
# Epoch : [220] ,  a_loss = 332.3762, d_loss: -1.4044 , db_loss: 1.5250
# Epoch : [221] ,  a_loss = 331.0377, d_loss: -1.4036 , db_loss: 1.6503
# Epoch : [222] ,  a_loss = 330.3247, d_loss: -1.3004 , db_loss: 1.7038
# Epoch : [223] ,  a_loss = 339.7197, d_loss: -1.3000 , db_loss: 1.5538
# Epoch : [224] ,  a_loss = 330.4388, d_loss: -1.5964 , db_loss: 1.6298
# Epoch : [225] ,  a_loss = 330.5600, d_loss: -1.5603 , db_loss: 1.6195
# Epoch : [226] ,  a_loss = 331.4329, d_loss: -1.7413 , db_loss: 1.6797
# Epoch : [227] ,  a_loss = 327.8953, d_loss: -1.8661 , db_loss: 1.6262
# Epoch : [228] ,  a_loss = 328.8463, d_loss: -0.7832 , db_loss: 1.7586
# Epoch : [229] ,  a_loss = 328.1007, d_loss: -1.2117 , db_loss: 1.6944
# Epoch : [230] ,  a_loss = 333.4862, d_loss: -1.2194 , db_loss: 1.6945
# Epoch : [231] ,  a_loss = 336.7667, d_loss: -1.4834 , db_loss: 1.7056
# Epoch : [232] ,  a_loss = 330.3271, d_loss: -1.2404 , db_loss: 1.6044
# Epoch : [233] ,  a_loss = 322.4216, d_loss: -1.3915 , db_loss: 1.7444
# Epoch : [234] ,  a_loss = 328.7124, d_loss: -1.2085 , db_loss: 1.7869
# Epoch : [235] ,  a_loss = 332.8728, d_loss: -0.9567 , db_loss: 1.7029
# Epoch : [236] ,  a_loss = 325.0317, d_loss: -1.5528 , db_loss: 1.5965
# Epoch : [237] ,  a_loss = 325.3782, d_loss: -1.8470 , db_loss: 1.7894
# Epoch : [238] ,  a_loss = 329.3347, d_loss: -1.6092 , db_loss: 1.6015
# Epoch : [239] ,  a_loss = 332.6536, d_loss: -1.1550 , db_loss: 1.6128
# Epoch : [240] ,  a_loss = 332.5920, d_loss: -1.2048 , db_loss: 1.7092
# Epoch : [241] ,  a_loss = 320.8654, d_loss: -1.1287 , db_loss: 1.8276
# Epoch : [242] ,  a_loss = 335.1607, d_loss: -1.4980 , db_loss: 1.6625
# Epoch : [243] ,  a_loss = 330.2157, d_loss: -1.3539 , db_loss: 1.6368
# Epoch : [244] ,  a_loss = 332.0506, d_loss: -1.0079 , db_loss: 1.6277
# Epoch : [245] ,  a_loss = 332.2034, d_loss: -1.2835 , db_loss: 1.6717
# Epoch : [246] ,  a_loss = 323.5639, d_loss: -1.5559 , db_loss: 1.6704
# Epoch : [247] ,  a_loss = 326.9017, d_loss: -1.6416 , db_loss: 1.7944
# Epoch : [248] ,  a_loss = 327.5092, d_loss: -1.5812 , db_loss: 1.7335
# Epoch : [249] ,  a_loss = 330.3425, d_loss: -1.9126 , db_loss: 1.6241
# Epoch : [250] ,  a_loss = 333.9794, d_loss: -1.6605 , db_loss: 1.5766
# Epoch : [251] ,  a_loss = 326.9405, d_loss: -1.9663 , db_loss: 1.7050
# Epoch : [252] ,  a_loss = 327.5768, d_loss: -1.2447 , db_loss: 1.7092
# Epoch : [253] ,  a_loss = 327.6546, d_loss: -1.2049 , db_loss: 1.6924
# Epoch : [254] ,  a_loss = 334.3284, d_loss: -1.7745 , db_loss: 1.7030
# Epoch : [255] ,  a_loss = 332.1700, d_loss: -1.8233 , db_loss: 1.6270
# Epoch : [256] ,  a_loss = 331.5903, d_loss: -1.5871 , db_loss: 1.6850
# Epoch : [257] ,  a_loss = 341.6763, d_loss: -1.1633 , db_loss: 1.6742
# Epoch : [258] ,  a_loss = 329.9297, d_loss: -1.2863 , db_loss: 1.6556
# Epoch : [259] ,  a_loss = 332.3294, d_loss: -1.4517 , db_loss: 1.6937
# Epoch : [260] ,  a_loss = 333.6468, d_loss: -1.6675 , db_loss: 1.6026
# Epoch : [261] ,  a_loss = 328.2801, d_loss: -1.4295 , db_loss: 1.6374
# Epoch : [262] ,  a_loss = 333.9024, d_loss: -1.7049 , db_loss: 1.6795
# Epoch : [263] ,  a_loss = 334.7236, d_loss: -1.3611 , db_loss: 1.7149
# Epoch : [264] ,  a_loss = 331.7383, d_loss: -1.7359 , db_loss: 1.7204
# Epoch : [265] ,  a_loss = 329.4585, d_loss: -1.0197 , db_loss: 1.6095
# Epoch : [266] ,  a_loss = 331.9238, d_loss: -1.9942 , db_loss: 1.6098
# Epoch : [267] ,  a_loss = 330.6971, d_loss: -1.5677 , db_loss: 1.6608
# Epoch : [268] ,  a_loss = 334.4111, d_loss: -1.6222 , db_loss: 1.6736
# Epoch : [269] ,  a_loss = 329.4854, d_loss: -1.1161 , db_loss: 1.6721
# Epoch : [270] ,  a_loss = 323.8508, d_loss: -1.3045 , db_loss: 1.6069
# Epoch : [271] ,  a_loss = 329.8324, d_loss: -1.3570 , db_loss: 1.5531
# Epoch : [272] ,  a_loss = 331.8242, d_loss: -1.3085 , db_loss: 1.6329
# Epoch : [273] ,  a_loss = 330.2582, d_loss: -1.2818 , db_loss: 1.5979
# Epoch : [274] ,  a_loss = 323.4716, d_loss: -1.9889 , db_loss: 1.7649
# Epoch : [275] ,  a_loss = 337.0713, d_loss: -1.5552 , db_loss: 1.6294
# Epoch : [276] ,  a_loss = 330.5671, d_loss: -1.5310 , db_loss: 1.6426
# Epoch : [277] ,  a_loss = 323.0902, d_loss: -1.2736 , db_loss: 1.6215
# Epoch : [278] ,  a_loss = 334.0058, d_loss: -0.5387 , db_loss: 1.5523
# Epoch : [279] ,  a_loss = 337.8245, d_loss: -1.1990 , db_loss: 1.5465
# Epoch : [280] ,  a_loss = 336.3123, d_loss: -1.1985 , db_loss: 1.6246
# Epoch : [281] ,  a_loss = 324.2139, d_loss: -1.4259 , db_loss: 1.5922
# Epoch : [282] ,  a_loss = 338.0885, d_loss: -1.6849 , db_loss: 1.5649
# Epoch : [283] ,  a_loss = 331.7803, d_loss: -1.4024 , db_loss: 1.6883
# Epoch : [284] ,  a_loss = 330.0139, d_loss: -1.3486 , db_loss: 1.7136
# Epoch : [285] ,  a_loss = 324.2724, d_loss: -1.1840 , db_loss: 1.6869
# Epoch : [286] ,  a_loss = 333.2862, d_loss: -1.5882 , db_loss: 1.6320
# Epoch : [287] ,  a_loss = 327.3604, d_loss: -2.1004 , db_loss: 1.6673
# Epoch : [288] ,  a_loss = 331.7397, d_loss: -1.3886 , db_loss: 1.6756
# Epoch : [289] ,  a_loss = 331.4733, d_loss: -0.8376 , db_loss: 1.6666
# Epoch : [290] ,  a_loss = 335.5099, d_loss: -1.4596 , db_loss: 1.5946
# Epoch : [291] ,  a_loss = 330.7057, d_loss: -1.3877 , db_loss: 1.6648
# Epoch : [292] ,  a_loss = 327.4186, d_loss: -1.6303 , db_loss: 1.6835
# Epoch : [293] ,  a_loss = 328.3424, d_loss: -1.0062 , db_loss: 1.6023
# Epoch : [294] ,  a_loss = 326.2020, d_loss: -1.8214 , db_loss: 1.6544
# Epoch : [295] ,  a_loss = 337.5616, d_loss: -2.1040 , db_loss: 1.6342
# Epoch : [296] ,  a_loss = 328.8022, d_loss: -1.9704 , db_loss: 1.6819
# Epoch : [297] ,  a_loss = 326.2281, d_loss: -1.6464 , db_loss: 1.6798
# Epoch : [298] ,  a_loss = 329.5807, d_loss: -1.7262 , db_loss: 1.5673
# Epoch : [299] ,  a_loss = 324.3389, d_loss: -1.8709 , db_loss: 1.7075
# latent_matrix shape (33506, 10)
# (33506,)
# None
# None
# Computing NMI ...
# Done !
# NMI = 0.8798515327528164
