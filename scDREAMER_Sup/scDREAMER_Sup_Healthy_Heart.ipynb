# %% [markdown]
# <a href="https://colab.research.google.com/github/Zafar-Lab/scDREAMER/blob/main/2109_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
import random
import numpy as np
import tensorflow as tf2
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# 2023-09-26 17:37:16.045413: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-26 17:37:16.691823: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
np.random.seed(0)
tf.set_random_seed(0)
random.seed(0)
tf2.random.set_seed(0)
tf2.keras.utils.set_random_seed(0)

# %%
import warnings
warnings.filterwarnings('ignore')
"""
# !pip install -U scipy==1.5.0
# !pip install scanpy==1.8.2
# !pip install -U scikit-learn
"""
# Out:
# '\n!pip install -U scipy==1.5.0\n!pip install scanpy==1.8.2\n!pip install -U scikit-learn\n'

# %% [markdown]
# Building model

# %%
name = "Healthy_Heart"

"""
NOTE:
Run setting as follows:
0: Supervised setting
10: 10 percent missing labels data
20: 20 percent missing labels data
50: 50 percent missing labels data
"""
run_setting = 0

# %%
"""

0: Supervised setting
10: 10% missing labels
20: 20% missing labels
50: 50% missing labels

"""

path = "/home/ajita/Documents/data_integration/"

data_path = {
    
"Immune_Human" : {0: path + "Immune/Immune_ALL_human.h5ad",
                  10: path + "Immune/Immune_Human_NA_0.1.h5ad",
                  20: path + "Immune/Immune_Human_NA_0.2.h5ad",
                  50: path + "Immune/Immune_Human_NA_0.5.h5ad"
                 },
    
"Human_Mouse" : {
                0: path + "hum_mou/hcl_mca_merged.h5ad"},
    
"Human_Retina" : {
                0: path + "Human_Retina/Human_Retina.h5ad"},
    
"Lung" : { 0: path + "Lung/Lung_atlas_public.h5ad",
          10: path + "Lung/Lung_NA_0.1.h5ad",
          20: path + "Lung/Lung_NA_0.2.h5ad",
          50: path + "Lung/Lung_NA_0.5.h5ad"
         },
    
"Healthy_Heart" : {
        0: path + "Healthy_Heart/Healthy_human_heart_adata_subset.h5ad",
        20: path + "Healthy_Heart/Healthy_human_heart_adata_NA_0.2.h5ad",
        50: path + "Healthy_Heart/Healthy_human_heart_adata_NA_0.5.h5ad"}
}


batch_key_dict = {'Immune_Human' : 'batch',
                 'Lung' : 'batch',
                 'Pancreas' : 'tech',
                 'Human_Mouse' : 'batch',
                 'Human_Retina': "Batch",
                 "Healthy_Heart" : "sampleID"
                 
                }

cell_type_key_dict = {
    
"Immune_Human" : {0: "final_annotation", 10: "final_annotation_NA",
                  20: "final_annotation_NA", 50: "final_annotation_NA"
                 },
    
"Human_Mouse" : {
                0: "celltype"},
    
"Human_Retina" : {
                0: "Subcluster"},
    
"Lung" : { 0: "cell_type",
          10: "cell_type_NA",
          20: "cell_type_NA",
          50: "cell_type_NA"
         },
    
"Healthy_Heart" : {
        0: "celltype_NA",
        20: "celltype_NA",
        50: "celltype_NA"},
    
"Human_Mouse" : {
     0: "celltype"
    }    
}
 
shuffle_type_dict = {
"Immune_Human" : {0: 1, 10: 2, 20: 2, 50: 2 },    
"Human_Retina" : { 0: 1},
"Lung" : { 0: 1,10: 2, 20: 2, 50: 2}, 
"Healthy_Heart" : {0: 1, 20: 1,50: 1},    
"Human_Mouse" : {0: 1}}

lr = {"lr_ae" : 0.0002, "lr_dis": 0.0007, "lr_bc": 0.0007}
lr_big_data = {"lr_ae" : 0.0001, "lr_dis": 0.00001, "lr_bc": 0.0007}

learning_rate = {
"Immune_Human" : {0: lr, 10: lr, 20: lr, 50: lr },    
"Human_Retina" : { 0: lr},
"Lung" : { 0: lr,10: lr, 20: lr, 50: lr}, 
"Healthy_Heart" : {0: lr_big_data, 20: lr_big_data, 50: lr_big_data},    
"Human_Mouse" : {0: {"lr_ae" : 0.00005, "lr_dis": 0.00001, "lr_bc": 0.0007}}}


# big datasets: 20 dimensions
latent_dim = {
                'Immune_Human' : 10,
                 'Lung' : 10,
                 'Pancreas' : 10,
                 'Human_Mouse' : 20,
                 'Human_Retina': 10,
                 "Healthy_Heart" : 20
    
            }

BS = {
"Immune_Human" : {0: 256, 10: 128, 20: 128, 50: 128 },    
"Human_Retina" : { 0: 256},
"Lung" : { 0: 256,10: 128, 20: 128, 50: 128}, 
"Healthy_Heart" : {0: 128, 20: 128,50: 128},    
"Human_Mouse" : {0: 128}}


epoch_dict = {
    'Immune_Human' : 300,
     'Lung' : 300,
     'Human_Mouse' : 300,
     'Human_Retina': 300,
     "Healthy_Heart" : 300
}

plot_cell_type_dict = {
                    "Healthy_Heart" : "celltype",
                    'Immune_Human' : 'final_annotation', 
                 'Lung' : 'cell_type',
                 'Pancreas' : 'celltype',
                 'Human_Mouse' : "celltype",
                 "Human_Retina":"Subcluster"
                    } 

"""
Below variable takes care of sparse matrix
If 1: pd.DataFrame.sparse.from_spmatrix(Ann.X) is used
If 0: pd.DataFrame(Ann.X)

By default 0, unless scarcity not handled by basis pandas operation
"""

sparseIP= {
        "Healthy_Heart" : 1,
    'Immune_Human' : 0, 
     'Lung' : 1,
     'Pancreas' : 0,
     'Human_Mouse' : 1,
     "Human_Retina": 0
}

# %%
# Add avg of losses

import src.model_big_dataset as model


run_config = tf.ConfigProto()

run_config.gpu_options.per_process_gpu_memory_fraction = 0.333
run_config.gpu_options.allow_growth = True

with tf.Session(config = run_config) as sess:

    dreamer = model.scDREAMER(
        sess,
        epoch = epoch_dict[name],
        dataset_name = data_path[name][run_setting],
        batch = batch_key_dict[name],
        cell_type = cell_type_key_dict[name][run_setting],
        plot_cell_type = plot_cell_type_dict[name],
        name = name,
        lr_ae = learning_rate[name][run_setting]['lr_ae'],
        lr_dis = learning_rate[name][run_setting]['lr_dis'],
        lr_bc = learning_rate[name][run_setting]['lr_bc'],
        batch_size = BS[name][run_setting],
        z_dim = latent_dim[name],
        shuffle_type = shuffle_type_dict[name][run_setting],
        sparseIP = sparseIP[name]
        )

    dreamer.train_cluster()
# Out:
# 2023-09-26 17:37:19.358710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5367 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:d8:00.0, compute capability: 7.5
# Loading dataset
# Preprocessing...
# here [10 11 11 ...  2  2  2]
# Shape self.data_train: (485511, 2000)
# Shape self.data_test: (485511, 2000)
# encoder input shape  Tensor("concat:0", shape=(?, 2147), dtype=float32)
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# decoder input shape  Tensor("concat_1:0", shape=(?, 167), dtype=float32)
# entering in for loop 1   512  -- > 256
# KL gaussian z Tensor("mul_13:0", shape=(?,), dtype=float32)
# KL gaussian l Tensor("mul_12:0", shape=(?,), dtype=float32)
# WARNING:tensorflow:From /home/ajita/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# scDREAMER on DataSet /home/ajita/Documents/data_integration/Healthy_Heart/Healthy_human_heart_adata_subset.h5ad ...
# 2023-09-26 17:39:18.650070: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# Epoch : [0] ,  a_loss = 219.2571, d_loss: -0.0040 , db_loss: 3.3380
# Epoch : [1] ,  a_loss = 210.8187, d_loss: -0.0009 , db_loss: 3.5409
# Epoch : [2] ,  a_loss = 197.2535, d_loss: -0.0004 , db_loss: 3.4339
# Epoch : [3] ,  a_loss = 197.1674, d_loss: -0.0002 , db_loss: 3.4448
# Epoch : [4] ,  a_loss = 195.7066, d_loss: -0.0001 , db_loss: 3.5559
# Epoch : [5] ,  a_loss = 196.2894, d_loss: -0.0001 , db_loss: 3.5333
# Epoch : [6] ,  a_loss = 192.8869, d_loss: -0.0001 , db_loss: 3.6430
# Epoch : [7] ,  a_loss = 195.7118, d_loss: -0.0000 , db_loss: 3.5588
# Epoch : [8] ,  a_loss = 183.9749, d_loss: -0.0000 , db_loss: 3.5640
# Epoch : [9] ,  a_loss = 177.5732, d_loss: 0.0000 , db_loss: 3.6173
# Epoch : [10] ,  a_loss = 187.5616, d_loss: 0.0000 , db_loss: 3.6688
# Epoch : [11] ,  a_loss = 178.9015, d_loss: -0.0000 , db_loss: 3.6013
# Epoch : [12] ,  a_loss = 182.3575, d_loss: -0.0000 , db_loss: 3.7927
# Epoch : [13] ,  a_loss = 181.3303, d_loss: -0.0000 , db_loss: 3.5882
# Epoch : [14] ,  a_loss = 179.1862, d_loss: 0.0000 , db_loss: 3.6429
# Epoch : [15] ,  a_loss = 179.4144, d_loss: 0.0000 , db_loss: 3.7739
# Epoch : [16] ,  a_loss = 188.3249, d_loss: 0.0000 , db_loss: 3.7586
# Epoch : [17] ,  a_loss = 186.8921, d_loss: 0.0000 , db_loss: 3.9814
# Epoch : [18] ,  a_loss = 183.3069, d_loss: 0.0000 , db_loss: 3.9320
# Epoch : [19] ,  a_loss = 175.4722, d_loss: 0.0000 , db_loss: 3.9454
# Epoch : [20] ,  a_loss = 173.6416, d_loss: -0.0000 , db_loss: 3.8527
# Epoch : [21] ,  a_loss = 182.6403, d_loss: 0.0000 , db_loss: 3.8746
# Epoch : [22] ,  a_loss = 190.0237, d_loss: -0.0000 , db_loss: 3.9008
# Epoch : [23] ,  a_loss = 180.3411, d_loss: 0.0000 , db_loss: 4.1242
# Epoch : [24] ,  a_loss = 179.2106, d_loss: 0.0000 , db_loss: 3.9805
# Epoch : [25] ,  a_loss = 176.5329, d_loss: 0.0000 , db_loss: 3.9464
# Epoch : [26] ,  a_loss = 177.3022, d_loss: 0.0000 , db_loss: 3.8455
# Epoch : [27] ,  a_loss = 177.9218, d_loss: -0.0000 , db_loss: 3.9987
# Epoch : [28] ,  a_loss = 173.9218, d_loss: 0.0000 , db_loss: 3.9891
# Epoch : [29] ,  a_loss = 183.4365, d_loss: 0.0000 , db_loss: 3.9278
# Epoch : [30] ,  a_loss = 183.1761, d_loss: -0.0000 , db_loss: 3.9430
# Epoch : [31] ,  a_loss = 175.9560, d_loss: 0.0000 , db_loss: 3.8726
# Epoch : [32] ,  a_loss = 173.8551, d_loss: 0.0000 , db_loss: 3.9845
# Epoch : [33] ,  a_loss = 165.9161, d_loss: 0.0000 , db_loss: 4.0114
# Epoch : [34] ,  a_loss = 184.6310, d_loss: -0.0000 , db_loss: 4.1092
# Epoch : [35] ,  a_loss = 181.8270, d_loss: 0.0000 , db_loss: 3.9829
# Epoch : [36] ,  a_loss = 188.0816, d_loss: 0.0000 , db_loss: 4.0992
# Epoch : [37] ,  a_loss = 178.0462, d_loss: -0.0000 , db_loss: 4.0595
# Epoch : [38] ,  a_loss = 175.8216, d_loss: -0.0000 , db_loss: 4.1143
# Epoch : [39] ,  a_loss = 178.1555, d_loss: 0.0000 , db_loss: 3.9983
# Epoch : [40] ,  a_loss = 172.5664, d_loss: 0.0000 , db_loss: 3.9082
# Epoch : [41] ,  a_loss = 180.0588, d_loss: -0.0000 , db_loss: 4.0117
# Epoch : [42] ,  a_loss = 181.5953, d_loss: 0.0000 , db_loss: 4.0097
# Epoch : [43] ,  a_loss = 193.4735, d_loss: 0.0000 , db_loss: 3.9439
# Epoch : [44] ,  a_loss = 184.7825, d_loss: -0.0000 , db_loss: 4.0317
# Epoch : [45] ,  a_loss = 181.8403, d_loss: -0.0000 , db_loss: 4.0115
# Epoch : [46] ,  a_loss = 187.5404, d_loss: -0.0000 , db_loss: 4.0108
# Epoch : [47] ,  a_loss = 177.2323, d_loss: 0.0000 , db_loss: 3.9988
# Epoch : [48] ,  a_loss = 185.5782, d_loss: 0.0000 , db_loss: 4.0803
# Epoch : [49] ,  a_loss = 186.2094, d_loss: -0.0000 , db_loss: 3.9879
# Epoch : [50] ,  a_loss = 189.7642, d_loss: -0.0000 , db_loss: 4.0145
# Epoch : [51] ,  a_loss = 170.6481, d_loss: -0.0000 , db_loss: 3.9978
# Epoch : [52] ,  a_loss = 167.2265, d_loss: -0.0000 , db_loss: 3.8892
# Epoch : [53] ,  a_loss = 178.1142, d_loss: -0.0000 , db_loss: 4.1127
# Epoch : [54] ,  a_loss = 185.6119, d_loss: -0.0000 , db_loss: 4.1136
# Epoch : [55] ,  a_loss = 180.0852, d_loss: 0.0000 , db_loss: 3.9835
# Epoch : [56] ,  a_loss = 187.3468, d_loss: 0.0000 , db_loss: 4.0321
# Epoch : [57] ,  a_loss = 169.5695, d_loss: -0.0000 , db_loss: 3.9836
# Epoch : [58] ,  a_loss = 175.6198, d_loss: -0.0000 , db_loss: 4.0591
# Epoch : [59] ,  a_loss = 178.1595, d_loss: -0.0000 , db_loss: 3.9037
# Epoch : [60] ,  a_loss = 181.6859, d_loss: -0.0000 , db_loss: 3.9642
# Epoch : [61] ,  a_loss = 181.3976, d_loss: -0.0000 , db_loss: 3.9955
# Epoch : [62] ,  a_loss = 178.7506, d_loss: 0.0000 , db_loss: 3.9833
# Epoch : [63] ,  a_loss = 177.5283, d_loss: 0.0000 , db_loss: 4.0608
# Epoch : [64] ,  a_loss = 181.9105, d_loss: 0.0000 , db_loss: 3.9605
# Epoch : [65] ,  a_loss = 167.0485, d_loss: 0.0000 , db_loss: 3.9721
# Epoch : [66] ,  a_loss = 167.4152, d_loss: -0.0000 , db_loss: 3.9723
# Epoch : [67] ,  a_loss = 174.5523, d_loss: 0.0000 , db_loss: 4.1936
# Epoch : [68] ,  a_loss = 179.6837, d_loss: -0.0000 , db_loss: 4.0044
# Epoch : [69] ,  a_loss = 177.6019, d_loss: 0.0000 , db_loss: 3.9942
# Epoch : [70] ,  a_loss = 183.6553, d_loss: 0.0000 , db_loss: 3.9455
# Epoch : [71] ,  a_loss = 179.8522, d_loss: -0.0000 , db_loss: 4.1034
# Epoch : [72] ,  a_loss = 175.8341, d_loss: 0.0000 , db_loss: 4.2156
# Epoch : [73] ,  a_loss = 180.0999, d_loss: -0.0000 , db_loss: 4.0098
# Epoch : [74] ,  a_loss = 180.3756, d_loss: 0.0000 , db_loss: 3.9891
# Epoch : [75] ,  a_loss = 185.8677, d_loss: 0.0000 , db_loss: 3.8788
# Epoch : [76] ,  a_loss = 183.1833, d_loss: 0.0000 , db_loss: 4.0542
# Epoch : [77] ,  a_loss = 177.3395, d_loss: 0.0000 , db_loss: 3.9901
# Epoch : [78] ,  a_loss = 182.5300, d_loss: -0.0000 , db_loss: 3.9826
# Epoch : [79] ,  a_loss = 179.7188, d_loss: 0.0000 , db_loss: 4.1095
# Epoch : [80] ,  a_loss = 177.1302, d_loss: -0.0000 , db_loss: 3.9233
# Epoch : [81] ,  a_loss = 176.9559, d_loss: 0.0000 , db_loss: 4.0692
# Epoch : [82] ,  a_loss = 185.5749, d_loss: 0.0000 , db_loss: 3.7594
# Epoch : [83] ,  a_loss = 193.2310, d_loss: 0.0000 , db_loss: 4.0236
# Epoch : [84] ,  a_loss = 181.3355, d_loss: 0.0000 , db_loss: 3.9961
# Epoch : [85] ,  a_loss = 171.5061, d_loss: 0.0000 , db_loss: 4.0462
# Epoch : [86] ,  a_loss = 177.2427, d_loss: 0.0000 , db_loss: 3.9442
# Epoch : [87] ,  a_loss = 179.1194, d_loss: -0.0000 , db_loss: 4.0516
# Epoch : [88] ,  a_loss = 181.5073, d_loss: 0.0000 , db_loss: 4.0073
# Epoch : [89] ,  a_loss = 176.6925, d_loss: 0.0000 , db_loss: 3.9505
# Epoch : [90] ,  a_loss = 173.5895, d_loss: 0.0000 , db_loss: 3.9720
# Epoch : [91] ,  a_loss = 182.5636, d_loss: -0.0000 , db_loss: 4.0440
# Epoch : [92] ,  a_loss = 187.8537, d_loss: 0.0000 , db_loss: 4.1150
# Epoch : [93] ,  a_loss = 168.6882, d_loss: 0.0000 , db_loss: 3.8984
# Epoch : [94] ,  a_loss = 181.0752, d_loss: 0.0000 , db_loss: 4.1482
# Epoch : [95] ,  a_loss = 184.0596, d_loss: -0.0000 , db_loss: 4.2810
# Epoch : [96] ,  a_loss = 181.5877, d_loss: 0.0000 , db_loss: 4.1404
# Epoch : [97] ,  a_loss = 178.8704, d_loss: -0.0000 , db_loss: 4.0340
# Epoch : [98] ,  a_loss = 172.7653, d_loss: 0.0000 , db_loss: 3.9930
# Epoch : [99] ,  a_loss = 183.0348, d_loss: 0.0000 , db_loss: 4.0243
# Epoch : [100] ,  a_loss = 175.2885, d_loss: 0.0000 , db_loss: 4.0526
# Epoch : [101] ,  a_loss = 186.6005, d_loss: 0.0000 , db_loss: 3.9684
# Epoch : [102] ,  a_loss = 169.5109, d_loss: 0.0000 , db_loss: 4.0280
# Epoch : [103] ,  a_loss = 183.1281, d_loss: -0.0000 , db_loss: 4.0787
# Epoch : [104] ,  a_loss = 175.0939, d_loss: -0.0000 , db_loss: 4.1464
# Epoch : [105] ,  a_loss = 176.0346, d_loss: 0.0000 , db_loss: 4.0642
# Epoch : [106] ,  a_loss = 174.3243, d_loss: -0.0000 , db_loss: 4.0296
# Epoch : [107] ,  a_loss = 178.6422, d_loss: 0.0000 , db_loss: 3.9803
# Epoch : [108] ,  a_loss = 175.1500, d_loss: 0.0000 , db_loss: 3.9138
# Epoch : [109] ,  a_loss = 173.9226, d_loss: 0.0000 , db_loss: 4.0371
# Epoch : [110] ,  a_loss = 172.5528, d_loss: 0.0000 , db_loss: 4.1554
# Epoch : [111] ,  a_loss = 179.9674, d_loss: 0.0000 , db_loss: 3.9432
# Epoch : [112] ,  a_loss = 177.8163, d_loss: 0.0000 , db_loss: 4.1526
# Epoch : [113] ,  a_loss = 171.9805, d_loss: 0.0000 , db_loss: 4.0849
# Epoch : [114] ,  a_loss = 182.3128, d_loss: 0.0000 , db_loss: 3.9556
# Epoch : [115] ,  a_loss = 175.1743, d_loss: -0.0000 , db_loss: 4.0704
# Epoch : [116] ,  a_loss = 181.1422, d_loss: -0.0000 , db_loss: 4.1429
# Epoch : [117] ,  a_loss = 179.0777, d_loss: 0.0000 , db_loss: 3.9225
# Epoch : [118] ,  a_loss = 193.9893, d_loss: -0.0000 , db_loss: 4.1335
# Epoch : [119] ,  a_loss = 190.6344, d_loss: 0.0000 , db_loss: 4.0946
# Epoch : [120] ,  a_loss = 169.4513, d_loss: 0.0000 , db_loss: 4.0960
# Epoch : [121] ,  a_loss = 180.8152, d_loss: -0.0000 , db_loss: 3.9180
# Epoch : [122] ,  a_loss = 172.5319, d_loss: 0.0000 , db_loss: 3.9250
# Epoch : [123] ,  a_loss = 181.4743, d_loss: -0.0000 , db_loss: 3.9899
# Epoch : [124] ,  a_loss = 174.6645, d_loss: -0.0000 , db_loss: 3.9611
# Epoch : [125] ,  a_loss = 169.6906, d_loss: 0.0000 , db_loss: 4.2003
# Epoch : [126] ,  a_loss = 178.3163, d_loss: -0.0000 , db_loss: 4.1336
# Epoch : [127] ,  a_loss = 176.5810, d_loss: 0.0000 , db_loss: 4.0851
# Epoch : [128] ,  a_loss = 180.6687, d_loss: 0.0000 , db_loss: 4.0183
# Epoch : [129] ,  a_loss = 177.2405, d_loss: 0.0000 , db_loss: 4.0863
# Epoch : [130] ,  a_loss = 182.4497, d_loss: 0.0000 , db_loss: 4.0341
# Epoch : [131] ,  a_loss = 174.7953, d_loss: 0.0000 , db_loss: 3.8844
# Epoch : [132] ,  a_loss = 179.5020, d_loss: 0.0000 , db_loss: 4.0885
# Epoch : [133] ,  a_loss = 170.1676, d_loss: -0.0000 , db_loss: 4.0651
# Epoch : [134] ,  a_loss = 178.9924, d_loss: 0.0000 , db_loss: 4.1911
# Epoch : [135] ,  a_loss = 166.6797, d_loss: 0.0000 , db_loss: 4.0519
# Epoch : [136] ,  a_loss = 174.6117, d_loss: -0.0000 , db_loss: 3.7937
# Epoch : [137] ,  a_loss = 174.6152, d_loss: 0.0000 , db_loss: 4.1035
# Epoch : [138] ,  a_loss = 167.9833, d_loss: -0.0000 , db_loss: 3.9703
# Epoch : [139] ,  a_loss = 168.2434, d_loss: 0.0000 , db_loss: 3.9748
# Epoch : [140] ,  a_loss = 171.8675, d_loss: -0.0000 , db_loss: 4.0286
# Epoch : [141] ,  a_loss = 175.8935, d_loss: -0.0000 , db_loss: 4.1730
# Epoch : [142] ,  a_loss = 172.7253, d_loss: -0.0000 , db_loss: 4.2160
# Epoch : [143] ,  a_loss = 175.9536, d_loss: -0.0000 , db_loss: 4.0596
# Epoch : [144] ,  a_loss = 176.3687, d_loss: 0.0000 , db_loss: 4.2365
# Epoch : [145] ,  a_loss = 179.4686, d_loss: 0.0000 , db_loss: 3.8799
# Epoch : [146] ,  a_loss = 175.2166, d_loss: -0.0000 , db_loss: 4.0618
# Epoch : [147] ,  a_loss = 169.9127, d_loss: -0.0000 , db_loss: 4.0576
# Epoch : [148] ,  a_loss = 176.4934, d_loss: 0.0000 , db_loss: 3.9589
# Epoch : [149] ,  a_loss = 172.0967, d_loss: -0.0000 , db_loss: 3.9895
# Epoch : [150] ,  a_loss = 170.9313, d_loss: 0.0000 , db_loss: 3.9783
# Epoch : [151] ,  a_loss = 178.1152, d_loss: 0.0000 , db_loss: 4.0514
# Epoch : [152] ,  a_loss = 177.1626, d_loss: -0.0000 , db_loss: 3.9465
# Epoch : [153] ,  a_loss = 175.7776, d_loss: 0.0000 , db_loss: 3.8884
# Epoch : [154] ,  a_loss = 177.3300, d_loss: 0.0000 , db_loss: 4.0521
# Epoch : [155] ,  a_loss = 173.5496, d_loss: -0.0000 , db_loss: 4.1147
# Epoch : [156] ,  a_loss = 172.7105, d_loss: -0.0000 , db_loss: 4.0811
# Epoch : [157] ,  a_loss = 178.3972, d_loss: 0.0000 , db_loss: 3.9893
# Epoch : [158] ,  a_loss = 190.0953, d_loss: -0.0000 , db_loss: 3.9983
# Epoch : [159] ,  a_loss = 169.0454, d_loss: 0.0000 , db_loss: 4.1012
# Epoch : [160] ,  a_loss = 168.0932, d_loss: -0.0000 , db_loss: 4.0733
# Epoch : [161] ,  a_loss = 172.5340, d_loss: 0.0000 , db_loss: 4.0963
# Epoch : [162] ,  a_loss = 169.7266, d_loss: -0.0000 , db_loss: 4.0703
# Epoch : [163] ,  a_loss = 171.8987, d_loss: -0.0000 , db_loss: 4.1336
# Epoch : [164] ,  a_loss = 178.0976, d_loss: 0.0000 , db_loss: 4.0790
# Epoch : [165] ,  a_loss = 166.6782, d_loss: 0.0000 , db_loss: 3.8932
# Epoch : [166] ,  a_loss = 173.6853, d_loss: 0.0000 , db_loss: 4.0433
# Epoch : [167] ,  a_loss = 176.6031, d_loss: 0.0000 , db_loss: 3.9246
# Epoch : [168] ,  a_loss = 160.1106, d_loss: 0.0000 , db_loss: 4.0833
# Epoch : [169] ,  a_loss = 180.3637, d_loss: -0.0000 , db_loss: 4.0050
# Epoch : [170] ,  a_loss = 170.7029, d_loss: 0.0000 , db_loss: 4.0512
# Epoch : [171] ,  a_loss = 177.3531, d_loss: -0.0000 , db_loss: 3.9428
# Epoch : [172] ,  a_loss = 168.6392, d_loss: -0.0000 , db_loss: 3.9926
# Epoch : [173] ,  a_loss = 176.2693, d_loss: 0.0000 , db_loss: 4.1662
# Epoch : [174] ,  a_loss = 181.5288, d_loss: 0.0000 , db_loss: 3.8612
# Epoch : [175] ,  a_loss = 174.2888, d_loss: -0.0000 , db_loss: 3.8962
# Epoch : [176] ,  a_loss = 176.0495, d_loss: 0.0000 , db_loss: 4.0342
# Epoch : [177] ,  a_loss = 184.5216, d_loss: 0.0000 , db_loss: 4.0012
# Epoch : [178] ,  a_loss = 183.8235, d_loss: -0.0000 , db_loss: 4.0267
# Epoch : [179] ,  a_loss = 177.8135, d_loss: 0.0000 , db_loss: 3.9670
# Epoch : [180] ,  a_loss = 168.9178, d_loss: -0.0000 , db_loss: 4.0131
# Epoch : [181] ,  a_loss = 171.8939, d_loss: 0.0000 , db_loss: 4.0033
# Epoch : [182] ,  a_loss = 166.1119, d_loss: -0.0000 , db_loss: 3.9791
# Epoch : [183] ,  a_loss = 172.1239, d_loss: 0.0000 , db_loss: 4.0054
# Epoch : [184] ,  a_loss = 173.1828, d_loss: 0.0000 , db_loss: 3.9308
# Epoch : [185] ,  a_loss = 175.3807, d_loss: 0.0000 , db_loss: 4.0380
# Epoch : [186] ,  a_loss = 179.1264, d_loss: 0.0000 , db_loss: 4.0965
# Epoch : [187] ,  a_loss = 166.0449, d_loss: 0.0000 , db_loss: 4.2264
# Epoch : [188] ,  a_loss = 162.4966, d_loss: 0.0000 , db_loss: 4.2657
# Epoch : [189] ,  a_loss = 180.1145, d_loss: 0.0000 , db_loss: 3.8727
# Epoch : [190] ,  a_loss = 180.3091, d_loss: -0.0000 , db_loss: 4.0339
# Epoch : [191] ,  a_loss = 163.5780, d_loss: 0.0000 , db_loss: 4.1151
# Epoch : [192] ,  a_loss = 169.4419, d_loss: 0.0000 , db_loss: 4.0673
# Epoch : [193] ,  a_loss = 163.9960, d_loss: 0.0000 , db_loss: 3.9350
# Epoch : [194] ,  a_loss = 182.5725, d_loss: -0.0000 , db_loss: 3.9840
# Epoch : [195] ,  a_loss = 166.5894, d_loss: 0.0000 , db_loss: 4.1312
# Epoch : [196] ,  a_loss = 187.7478, d_loss: 0.0000 , db_loss: 4.1380
# Epoch : [197] ,  a_loss = 172.6090, d_loss: 0.0000 , db_loss: 4.0258
# Epoch : [198] ,  a_loss = 179.6680, d_loss: 0.0000 , db_loss: 4.0163
# Epoch : [199] ,  a_loss = 156.9967, d_loss: 0.0000 , db_loss: 4.0894
# Epoch : [200] ,  a_loss = 160.8677, d_loss: 0.0000 , db_loss: 4.0169
# Epoch : [201] ,  a_loss = 178.5164, d_loss: -0.0000 , db_loss: 4.0633
# Epoch : [202] ,  a_loss = 176.5721, d_loss: 0.0000 , db_loss: 4.1493
# Epoch : [203] ,  a_loss = 181.9244, d_loss: 0.0000 , db_loss: 3.8978
# Epoch : [204] ,  a_loss = 168.9315, d_loss: 0.0000 , db_loss: 4.0633
# Epoch : [205] ,  a_loss = 179.3240, d_loss: 0.0000 , db_loss: 4.0366
# Epoch : [206] ,  a_loss = 174.5686, d_loss: -0.0000 , db_loss: 3.7304
# Epoch : [207] ,  a_loss = 172.4648, d_loss: 0.0000 , db_loss: 4.0621
# Epoch : [208] ,  a_loss = 180.7852, d_loss: -0.0000 , db_loss: 3.9835
# Epoch : [209] ,  a_loss = 176.8263, d_loss: -0.0000 , db_loss: 4.0428
# Epoch : [210] ,  a_loss = 174.1581, d_loss: 0.0000 , db_loss: 4.0233
# Epoch : [211] ,  a_loss = 165.8561, d_loss: 0.0000 , db_loss: 3.9935
# Epoch : [212] ,  a_loss = 174.3126, d_loss: 0.0000 , db_loss: 4.0181
# Epoch : [213] ,  a_loss = 183.7430, d_loss: -0.0000 , db_loss: 3.8643
# Epoch : [214] ,  a_loss = 172.3743, d_loss: -0.0000 , db_loss: 3.8532
# Epoch : [215] ,  a_loss = 179.9268, d_loss: 0.0000 , db_loss: 4.0937
# Epoch : [216] ,  a_loss = 179.1873, d_loss: 0.0000 , db_loss: 4.0059
# Epoch : [217] ,  a_loss = 199.2742, d_loss: 0.0000 , db_loss: 3.9929
# Epoch : [218] ,  a_loss = 174.1411, d_loss: 0.0000 , db_loss: 4.2856
# Epoch : [219] ,  a_loss = 177.8878, d_loss: -0.0000 , db_loss: 3.9827
# Epoch : [220] ,  a_loss = 182.5468, d_loss: -0.0000 , db_loss: 4.0356
# Epoch : [221] ,  a_loss = 184.7785, d_loss: 0.0000 , db_loss: 4.0611
# Epoch : [222] ,  a_loss = 161.7832, d_loss: 0.0000 , db_loss: 4.1900
# Epoch : [223] ,  a_loss = 169.0556, d_loss: 0.0000 , db_loss: 3.9367
# Epoch : [224] ,  a_loss = 187.5471, d_loss: -0.0000 , db_loss: 4.1327
# Epoch : [225] ,  a_loss = 173.6685, d_loss: 0.0000 , db_loss: 3.8411
# Epoch : [226] ,  a_loss = 175.9044, d_loss: 0.0000 , db_loss: 3.9037
# Epoch : [227] ,  a_loss = 177.3418, d_loss: 0.0000 , db_loss: 3.9631
# Epoch : [228] ,  a_loss = 179.5442, d_loss: 0.0000 , db_loss: 3.9455
# Epoch : [229] ,  a_loss = 173.0346, d_loss: 0.0000 , db_loss: 4.0970
# Epoch : [230] ,  a_loss = 193.6163, d_loss: -0.0000 , db_loss: 4.1939
# Epoch : [231] ,  a_loss = 174.6852, d_loss: -0.0000 , db_loss: 4.0117
# Epoch : [232] ,  a_loss = 176.0578, d_loss: 0.0000 , db_loss: 4.0092
# Epoch : [233] ,  a_loss = 183.2316, d_loss: -0.0000 , db_loss: 4.1085
# Epoch : [234] ,  a_loss = 181.9088, d_loss: 0.0000 , db_loss: 3.8897
# Epoch : [235] ,  a_loss = 178.3688, d_loss: -0.0000 , db_loss: 3.9519
# Epoch : [236] ,  a_loss = 168.8150, d_loss: 0.0000 , db_loss: 3.9821
# Epoch : [237] ,  a_loss = 175.4630, d_loss: -0.0000 , db_loss: 3.9520
# Epoch : [238] ,  a_loss = 162.0439, d_loss: -0.0000 , db_loss: 4.0268
# Epoch : [239] ,  a_loss = 184.6376, d_loss: 0.0000 , db_loss: 3.8413
# Epoch : [240] ,  a_loss = 179.4876, d_loss: 0.0000 , db_loss: 4.1785
# Epoch : [241] ,  a_loss = 172.2345, d_loss: 0.0000 , db_loss: 3.9842
# Epoch : [242] ,  a_loss = 174.3215, d_loss: -0.0000 , db_loss: 4.1265
# Epoch : [243] ,  a_loss = 177.6888, d_loss: 0.0000 , db_loss: 3.9744
# Epoch : [244] ,  a_loss = 172.3762, d_loss: 0.0000 , db_loss: 3.9690
# Epoch : [245] ,  a_loss = 190.5789, d_loss: 0.0000 , db_loss: 3.9711
# Epoch : [246] ,  a_loss = 176.2438, d_loss: -0.0000 , db_loss: 3.9916
# Epoch : [247] ,  a_loss = 177.0381, d_loss: -0.0000 , db_loss: 3.9373
# Epoch : [248] ,  a_loss = 180.1100, d_loss: -0.0000 , db_loss: 3.9330
# Epoch : [249] ,  a_loss = 185.2665, d_loss: 0.0000 , db_loss: 3.9640
# Epoch : [250] ,  a_loss = 177.9062, d_loss: 0.0000 , db_loss: 3.8677
# Epoch : [251] ,  a_loss = 178.0505, d_loss: 0.0000 , db_loss: 3.9260
# Epoch : [252] ,  a_loss = 174.2009, d_loss: -0.0000 , db_loss: 4.0628
# Epoch : [253] ,  a_loss = 173.5345, d_loss: 0.0000 , db_loss: 4.1604
# Epoch : [254] ,  a_loss = 174.8481, d_loss: -0.0000 , db_loss: 3.9959
# Epoch : [255] ,  a_loss = 174.5353, d_loss: 0.0000 , db_loss: 3.8836
# Epoch : [256] ,  a_loss = 185.4512, d_loss: 0.0000 , db_loss: 4.0165
# Epoch : [257] ,  a_loss = 186.8446, d_loss: 0.0000 , db_loss: 3.9172
# Epoch : [258] ,  a_loss = 178.0053, d_loss: -0.0000 , db_loss: 4.0135
# Epoch : [259] ,  a_loss = 190.3515, d_loss: -0.0000 , db_loss: 3.9986
# Epoch : [260] ,  a_loss = 191.2267, d_loss: -0.0000 , db_loss: 4.0715
# Epoch : [261] ,  a_loss = 187.8009, d_loss: -0.0000 , db_loss: 3.9904
# Epoch : [262] ,  a_loss = 182.7092, d_loss: -0.0000 , db_loss: 3.9133
# Epoch : [263] ,  a_loss = 195.8340, d_loss: 0.0000 , db_loss: 4.1096
# Epoch : [264] ,  a_loss = 177.8127, d_loss: 0.0000 , db_loss: 3.9635
# Epoch : [265] ,  a_loss = 176.9588, d_loss: 0.0000 , db_loss: 3.9980
# Epoch : [266] ,  a_loss = 184.2203, d_loss: 0.0000 , db_loss: 4.0535
# Epoch : [267] ,  a_loss = 175.8686, d_loss: 0.0000 , db_loss: 3.9884
# Epoch : [268] ,  a_loss = 175.5574, d_loss: 0.0000 , db_loss: 4.0184
# Epoch : [269] ,  a_loss = 167.5011, d_loss: 0.0000 , db_loss: 3.9903
# Epoch : [270] ,  a_loss = 180.3439, d_loss: 0.0000 , db_loss: 4.0279
# Epoch : [271] ,  a_loss = 174.1953, d_loss: -0.0000 , db_loss: 3.9482
# Epoch : [272] ,  a_loss = 181.1864, d_loss: 0.0000 , db_loss: 3.9175
# Epoch : [273] ,  a_loss = 168.7017, d_loss: 0.0000 , db_loss: 4.0122
# Epoch : [274] ,  a_loss = 171.6463, d_loss: -0.0000 , db_loss: 3.9240
# Epoch : [275] ,  a_loss = 179.6812, d_loss: 0.0000 , db_loss: 3.9634
# Epoch : [276] ,  a_loss = 179.7159, d_loss: -0.0000 , db_loss: 3.9397
# Epoch : [277] ,  a_loss = 178.0299, d_loss: -0.0000 , db_loss: 3.9298
# Epoch : [278] ,  a_loss = 180.9274, d_loss: -0.0000 , db_loss: 3.9833
# Epoch : [279] ,  a_loss = 167.3806, d_loss: 0.0000 , db_loss: 3.9150
# Epoch : [280] ,  a_loss = 194.2802, d_loss: 0.0000 , db_loss: 3.7957
# Epoch : [281] ,  a_loss = 174.8949, d_loss: -0.0000 , db_loss: 3.9595
# Epoch : [282] ,  a_loss = 175.4751, d_loss: 0.0000 , db_loss: 3.9644
# Epoch : [283] ,  a_loss = 173.3580, d_loss: 0.0000 , db_loss: 4.1566
# Epoch : [284] ,  a_loss = 173.1308, d_loss: -0.0000 , db_loss: 4.1308
# Epoch : [285] ,  a_loss = 195.4582, d_loss: 0.0000 , db_loss: 4.0663
# Epoch : [286] ,  a_loss = 177.4345, d_loss: -0.0000 , db_loss: 4.0057
# Epoch : [287] ,  a_loss = 174.8297, d_loss: 0.0000 , db_loss: 3.8544
# Epoch : [288] ,  a_loss = 181.9699, d_loss: 0.0000 , db_loss: 3.9855
# Epoch : [289] ,  a_loss = 173.5973, d_loss: 0.0000 , db_loss: 3.9347
# Epoch : [290] ,  a_loss = 181.1614, d_loss: 0.0000 , db_loss: 4.0444
# Epoch : [291] ,  a_loss = 178.6119, d_loss: 0.0000 , db_loss: 3.9566
# Epoch : [292] ,  a_loss = 185.4013, d_loss: -0.0000 , db_loss: 3.9179
# Epoch : [293] ,  a_loss = 176.0553, d_loss: -0.0000 , db_loss: 3.9953
# Epoch : [294] ,  a_loss = 183.1952, d_loss: 0.0000 , db_loss: 4.1899
# Epoch : [295] ,  a_loss = 179.9726, d_loss: 0.0000 , db_loss: 3.9002
# Epoch : [296] ,  a_loss = 168.5472, d_loss: 0.0000 , db_loss: 4.0186
# Epoch : [297] ,  a_loss = 180.2772, d_loss: 0.0000 , db_loss: 4.2662
# Epoch : [298] ,  a_loss = 176.2325, d_loss: -0.0000 , db_loss: 3.9312
# Epoch : [299] ,  a_loss = 174.2710, d_loss: 0.0000 , db_loss: 4.0341
# latent_matrix shape (485511, 20)
# (485511,)
# None
# None
# Computing NMI ...
# Done !
# NMI = 0.8144388366463782
