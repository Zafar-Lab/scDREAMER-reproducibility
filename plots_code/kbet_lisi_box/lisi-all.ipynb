# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import rc
mpl.rcParams["figure.dpi"] = 200

rc("axes", linewidth=2)

# %%
datasets = ["Immune_Human", "Lung", "Pancreas"]  # ,'Human_Retina']
# datasets = ['Human_Mouse']
method_color_dct = {
    "scVI": "#28DDED",
    "Harmony": "#ED7A28",
    "Seurat": "#994363",
    "BBKNN": "#B626D3",
    "Scanorama": "#EDBF28",
    "INSCT": "#286CED",
    "LIGER": "#90EE90",
    "fastMNN": "#FFB6C1",
    "iMAP": "#964B00",
    "scDML": "#6F3AF9",
    "scDREAMER": "#086E28",
    "scANVI": "#c5b0d5",
    "scGEN": "#d62829",
    "scDREAMER-Sup": "#113f0a",
}
method_color_dct.update(
    {
        "scDREAMER-Sup-10": method_color_dct["scDREAMER-Sup"],
        "scDREAMER-Sup-20": method_color_dct["scDREAMER-Sup"],
        "scDREAMER-Sup-50": method_color_dct["scDREAMER-Sup"],
        "scANVI-10": method_color_dct["scANVI"],
        "scANVI-20": method_color_dct["scANVI"],
        "scANVI-50": method_color_dct["scANVI"],
        "scGEN-10": method_color_dct["scGEN"],
        "scGEN-20": method_color_dct["scGEN"],
        "scGEN-50": method_color_dct["scGEN"],
    }
)

# %% [markdown]
# # unsup

# %%
plot_save_path = "/home/krushna/Documents/Data_integration/Figures/lisi/"
base_path = "/home/krushna/Documents/Data_integration/Othermethods/"
for dataset in datasets:
    ilisi_paths = [
        "scvi/kbet_lisi/" + dataset + "_ilisi.csv",
        "harmony/kbet_lisi/" + dataset + "_ilisi.csv",
        "seurat/kbet_lisi/" + dataset + "_ilisi.csv",
        "bbknn/kbet_lisi/" + dataset + "_ilisi.csv",
        "scanorama/kbet_lisi/" + dataset + "_ilisi.csv",
        "insct/kbet_lisi/" + dataset + "_ilisi.csv",
        "liger/kbet_lisi/" + dataset + "_ilisi.csv",
        "imap/kbet_lisi/" + dataset + "_ilisi.csv",
        "scdml/kbet_lisi/" + dataset + "_ilisi.csv",
        "ourmethod/kbet_lisi/" + dataset + "_ilisi.csv",
    ]
    clisi_paths = [
        "scvi/kbet_lisi/" + dataset + "_clisi.csv",
        "harmony/kbet_lisi/" + dataset + "_clisi.csv",
        "seurat/kbet_lisi/" + dataset + "_clisi.csv",
        "bbknn/kbet_lisi/" + dataset + "_clisi.csv",
        "scanorama/kbet_lisi/" + dataset + "_clisi.csv",
        "insct/kbet_lisi/" + dataset + "_clisi.csv",
        "liger/kbet_lisi/" + dataset + "_clisi.csv",
        "imap/kbet_lisi/" + dataset + "_clisi.csv",
        "scdml/kbet_lisi/" + dataset + "_clisi.csv",
        "ourmethod/kbet_lisi/" + dataset + "_clisi.csv",
    ]
    print(dataset)
    labels_to_plot = [
        "scVI",
        "Harmony",
        "Seurat",
        "BBKNN",
        "Scanorama",
        "INSCT",
        "LIGER",
        "iMAP",
        "scDML",
        "scDREAMER",
    ]
    ilisi_values = [np.genfromtxt(base_path + path) for path in ilisi_paths]
    clisi_values = [np.genfromtxt(base_path + path) for path in clisi_paths]
    medianprops = dict(color="black")

    bp = plt.boxplot(
        ilisi_values, labels=labels_to_plot, patch_artist=True, medianprops=medianprops
    )  # ,vert=False)
    plt.subplot(111).spines["right"].set_visible(False)
    plt.subplot(111).spines["top"].set_visible(False)
    plt.xticks(rotation=75)
    plt.ylabel("iLISI", fontsize=15, fontname="Arial", fontweight="bold")
    for box, label in zip(bp["boxes"], labels_to_plot):
        box.set_facecolor(method_color_dct[label])

    plt.gcf().subplots_adjust(bottom=0.35)
    ax = plt.gca()
    for tick in ax.xaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight("bold")
    for tick in ax.yaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight("bold")
    plt.tight_layout()
    plt.ylim(bottom=0)
    plt.savefig(
        plot_save_path + dataset + "_ilisi.png", transparent=True, bbox_inches="tight"
    )
    plt.show()

    bp = plt.boxplot(
        clisi_values, labels=labels_to_plot, patch_artist=True, medianprops=medianprops
    )
    plt.subplot(111).spines["right"].set_visible(False)
    plt.subplot(111).spines["top"].set_visible(False)
    plt.xticks(rotation=75)
    plt.ylabel("cLISI", fontsize=15, fontname="Arial", fontweight="bold")
    for box, label in zip(bp["boxes"], labels_to_plot):
        box.set_facecolor(method_color_dct[label])

    ax = plt.gca()
    plt.gcf().subplots_adjust(bottom=0.35)
    for tick in ax.xaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight("bold")
    for tick in ax.yaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight("bold")
    plt.ylim(bottom=0)
    plt.tight_layout()
    plt.savefig(
        plot_save_path + dataset + "_clisi.png", transparent=True, bbox_inches="tight"
    )
    plt.show()

# %%
def plot_box_multi(x, y, hue, palette, y_label, save=None):
    ax = sns.boxplot(x=x, y=y, hue=hue, palette=palette)
    plt.xticks(rotation=90)
    ax.legend(
        loc="center left",
        bbox_to_anchor=(1, 0.5),
        prop={"family": "Arial", "weight": "bold", "size": 14},
    )
    ax.get_legend().remove()
    for tick in ax.xaxis.get_major_ticks():
        tick.label1.set_fontsize(14)
        tick.label1.set_fontweight("bold")
    for tick in ax.yaxis.get_major_ticks():
        tick.label1.set_fontsize(14)
        tick.label1.set_fontweight("bold")
    ax.set_ylabel(y_label, fontsize=15, fontname="Arial", fontweight="bold")
    ax.set_xlabel(
        "Percentage of missing cell type labels",
        fontsize=15,
        fontname="Arial",
        fontweight="bold",
    )
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    if save:
        print("plot saving at : ", save + y_label + ".png")
        plt.savefig(save + y_label + ".png", transparent=True, bbox_inches="tight")
    plt.show()

# %%
import pandas as pd
import seaborn as sns

plot_save_path_sup = "/home/krushna/Documents/Data_integration/Figures/lisi/lisi_sup/"
base_path = "/home/krushna/Documents/Data_integration/Othermethods/"
datasets = ["Lung", "Immune_Human"]
for dataset in datasets:
    print(dataset)
    ilisi_paths = [
        "scGen/kbet_lisi/" + dataset + "_ilisi.csv",
        "scGen/NA_102050/" + dataset + "_NA_0.1_ilisi.csv",
        "scGen/NA_102050/" + dataset + "_NA_0.2_ilisi.csv",
        "scGen/NA_102050/" + dataset + "_NA_0.5_ilisi.csv",
        "scanvi/kbet_lisi/" + dataset + "_ilisi.csv",
        "scanvi/NA_102050/" + dataset + "_NA_0.1_ilisi.csv",
        "scanvi/NA_102050/" + dataset + "_NA_0.2_ilisi.csv",
        "scanvi/NA_102050/" + dataset + "_NA_0.5_ilisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_ilisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_NA_0.1_ilisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_NA_0.2_ilisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_NA_0.5_ilisi.csv",
    ]
    clisi_paths = [
        "scGen/kbet_lisi/" + dataset + "_clisi.csv",
        "scGen/NA_102050/" + dataset + "_NA_0.1_clisi.csv",
        "scGen/NA_102050/" + dataset + "_NA_0.2_clisi.csv",
        "scGen/NA_102050/" + dataset + "_NA_0.5_clisi.csv",
        "scanvi/kbet_lisi/" + dataset + "_clisi.csv",
        "scanvi/NA_102050/" + dataset + "_NA_0.1_clisi.csv",
        "scanvi/NA_102050/" + dataset + "_NA_0.2_clisi.csv",
        "scanvi/NA_102050/" + dataset + "_NA_0.5_clisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_clisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_NA_0.1_clisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_NA_0.2_clisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_NA_0.5_clisi.csv",
    ]
    labels_to_plot = [
        "scGEN",
        "scGEN-10",
        "scGEN-20",
        "scGEN-50",
        "scANVI",
        "scANVI-10",
        "scANVI-20",
        "scANVI-50",
        "scDREAMER-Sup",
        "scDREAMER-Sup-10",
        "scDREAMER-Sup-20",
        "scDREAMER-Sup-50",
    ]
    lisi_data = pd.DataFrame([], columns=["iLISI", "method", "Percentage_wrong"])
    for path, method in zip(ilisi_paths, labels_to_plot):
        temp = pd.DataFrame(np.genfromtxt(base_path + path), columns=["iLISI"])
        temp["method"] = method.rsplit("-", 1)[0]
        if method == "scDREAMER-Sup":
            temp["method"] = method
            temp["Percentage_wrong"] = 0
        elif len(method.split("-")) == 1:
            temp["Percentage_wrong"] = 0
        else:
            temp["Percentage_wrong"] = method.rsplit("-", 1)[1]
        lisi_data = pd.concat([lisi_data, temp], axis=0)
    plot_box_multi(
        x=lisi_data["Percentage_wrong"],
        y=lisi_data["iLISI"],
        hue=lisi_data["method"],
        palette=method_color_dct,
        y_label="iLISI",
        save=plot_save_path_sup + dataset + "_sup_ilisi.png",
    )

    lisi_data = pd.DataFrame([], columns=["cLISI", "method", "Percentage_wrong"])
    for path, method in zip(clisi_paths, labels_to_plot):
        temp = pd.DataFrame(np.genfromtxt(base_path + path), columns=["cLISI"])
        temp["method"] = method.rsplit("-", 1)[0]
        if method == "scDREAMER-Sup":
            temp["method"] = method
            temp["Percentage_wrong"] = 0
        elif len(method.split("-")) == 1:
            temp["Percentage_wrong"] = 0
        else:
            temp["Percentage_wrong"] = method.rsplit("-", 1)[1]
        lisi_data = pd.concat([lisi_data, temp], axis=0)
    plot_box_multi(
        x=lisi_data["Percentage_wrong"],
        y=lisi_data["cLISI"],
        hue=lisi_data["method"],
        palette=method_color_dct,
        y_label="cLISI",
        save=plot_save_path_sup + dataset + "_sup_clisi.png",
    )

# %% [markdown]
# # unsup + sup

# %%
# plot sup+unsup
datasets = ["Human_Retina"]
plot_save_path = "/home/krushna/Documents/Data_integration/Figures/lisi/"
base_path = "/home/krushna/Documents/Data_integration/Othermethods/"
for dataset in datasets:
    ilisi_paths = [
        "scvi/kbet_lisi/" + dataset + "_ilisi.csv",
        "harmony/kbet_lisi/" + dataset + "_ilisi.csv",
        "seurat/kbet_lisi/" + dataset + "_ilisi.csv",
        "bbknn/kbet_lisi/" + dataset + "_ilisi.csv",
        "scanorama/kbet_lisi/" + dataset + "_ilisi.csv",
        "insct/kbet_lisi/" + dataset + "_ilisi.csv",
        "liger/kbet_lisi/" + dataset + "_ilisi.csv",
        "imap/kbet_lisi/" + dataset + "_ilisi.csv",
        "scdml/kbet_lisi/" + dataset + "_ilisi.csv",
        "ourmethod/kbet_lisi/" + dataset + "_ilisi.csv",
        "scGen/kbet_lisi/" + dataset + "_ilisi.csv",
        "scanvi/kbet_lisi/" + dataset + "_ilisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_ilisi.csv",
    ]
    clisi_paths = [
        "scvi/kbet_lisi/" + dataset + "_clisi.csv",
        "harmony/kbet_lisi/" + dataset + "_clisi.csv",
        "seurat/kbet_lisi/" + dataset + "_clisi.csv",
        "bbknn/kbet_lisi/" + dataset + "_clisi.csv",
        "scanorama/kbet_lisi/" + dataset + "_clisi.csv",
        "insct/kbet_lisi/" + dataset + "_clisi.csv",
        "liger/kbet_lisi/" + dataset + "_clisi.csv",
        "imap/kbet_lisi/" + dataset + "_clisi.csv",
        "scdml/kbet_lisi/" + dataset + "_clisi.csv",
        "ourmethod/kbet_lisi/" + dataset + "_clisi.csv",
        "scGen/kbet_lisi/" + dataset + "_clisi.csv",
        "scanvi/kbet_lisi/" + dataset + "_clisi.csv",
        "ourmethod/kbet_lisi/supervised/" + dataset + "_clisi.csv",
    ]
    print(dataset)
    labels_to_plot = [
        "scVI",
        "Harmony",
        "Seurat",
        "BBKNN",
        "Scanorama",
        "INSCT",
        "LIGER",
        "iMAP",
        "scDML",
        "scDREAMER",
        "scGEN",
        "scANVI",
        "scDREAMER-Sup",
    ]
    ilisi_values = [np.genfromtxt(base_path + path) for path in ilisi_paths]
    clisi_values = [np.genfromtxt(base_path + path) for path in clisi_paths]
    medianprops = dict(color="black")

    fig, ax = plt.subplots()
    boxplot_dict = ax.boxplot(ilisi_values, labels=labels_to_plot, medianprops=medianprops, patch_artist=True)
    plt.ylim(bottom=0)

    ax.tick_params(labelbottom = False, bottom = False)

    # vertical line
    boxes = boxplot_dict['boxes']
    xmin, _, xmax, _ = boxes[0].get_extents().bounds
    box_width = xmax-xmin

    mi,mx = ax.get_ylim()
    sep_line_x = 10.5# + box_width
    line = plt.plot((sep_line_x,sep_line_x), (mi-0.05*mx,mx*1.05) , color='black', linestyle='--', clip_on = False)

    plt.subplot(111).spines["right"].set_visible(False)
    plt.subplot(111).spines["top"].set_visible(False)
    plt.xticks(rotation=75)
    plt.ylabel("iLISI", fontsize=15, fontname="Arial", fontweight="bold")
    for box, label in zip(boxplot_dict["boxes"], labels_to_plot):
        box.set_facecolor(method_color_dct[label])

    plt.gcf().subplots_adjust(bottom=0.35)
    ax = plt.gca()
    for tick in ax.xaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight("bold")
    for tick in ax.yaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight("bold")
    plt.tight_layout()

    dy_legend = 0.07
    ax.text(4, mi-(mx-mi)*(dy_legend),  'Unsupervised', fontsize = 13, fontname='Arial', weight = 'bold')
    ax.text(10.8, mi-(mx-mi)*(dy_legend), 'Supervised', fontsize = 13, fontname='Arial', weight = 'bold', color='#000080')

    plt.savefig(
        plot_save_path + dataset + "_ilisi.png", transparent=True, bbox_inches="tight"
    )
    plt.show()


    fig, ax = plt.subplots()
    boxplot_dict = ax.boxplot(clisi_values, labels=labels_to_plot, medianprops=medianprops, patch_artist=True)
    plt.ylim(bottom=0)

    ax.tick_params(labelbottom = False, bottom = False)

    # vertical line
    boxes = boxplot_dict['boxes']

    mi,mx = ax.get_ylim()
    sep_line_x =  10.5
    line = plt.plot((sep_line_x,sep_line_x), (mi-0.05*mx,mx*1.05) , color='black', linestyle='--', clip_on = False)


    plt.subplot(111).spines["right"].set_visible(False)
    plt.subplot(111).spines["top"].set_visible(False)
    plt.xticks(rotation=75)
    plt.ylabel("cLISI", fontsize=15, fontname="Arial", fontweight="bold")
    for box, label in zip(boxplot_dict["boxes"], labels_to_plot):
        box.set_facecolor(method_color_dct[label])

    plt.gcf().subplots_adjust(bottom=0.35)
    ax = plt.gca()
    for tick in ax.xaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight("bold")
    for tick in ax.yaxis.get_major_ticks():
        tick.label1.set_fontsize(15)
        tick.label1.set_fontweight("bold")
    plt.tight_layout()

    dy_legend = 0.07
    ax.text(4, mi-(mx-mi)*(dy_legend),  'Unsupervised', fontsize = 13, fontname='Arial', weight = 'bold')
    ax.text(10.8, mi-(mx-mi)*(dy_legend), 'Supervised', fontsize = 13, fontname='Arial', weight = 'bold', color='#000080')

    plt.savefig(
        plot_save_path + dataset + "_clisi.png", transparent=True, bbox_inches="tight"
    )
    plt.show()
